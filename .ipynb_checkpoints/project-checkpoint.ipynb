# %% [markdown]
# <h1 style="font-size:40px;"><center>Counting corners in polygons with a<br> Convolutional Neural Network
# </center></h1>

# %% [markdown]
# In this notebook, I design a CNN network to count the corners of polygons in images from an archive. Images are found in the same working directory as this notebook along with the target labels.
#
# The number of corners ranges from 3 to 10.
#
#
#
# Dictionary
#
# *Accuracy*: The proportion of correct predictions

# %%
import numpy as np
import tensorflow as tf
import time

import numpy as np
import tensorflow as tf
import time

from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input, Activation, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Nadam
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers

from sklearn.metrics import *

import matplotlib
import matplotlib.pyplot as plt

import imageio.v2 as imageio

# %% [markdown]
# Define a function to load the polygon images

# %%
# functions for loading the images from the course Deep learning, Lund university (2022)
def loadImages(folder,trgFile,n):
    def load_pics(folder,n):
        imgs = []
        for i in range(n):
            img = imageio.imread(folder+"img_{:05}.png".format(i+1))
            ch = img[:,:,0]
            imgs.append(ch)
        return np.array(imgs)

    def load_labels(fn):
        return np.loadtxt(fn, usecols=0)

    pic = load_pics(folder+"/", n)
    ndata, width, height = pic.shape

    inp = (pic/np.float32(255)).reshape(n, width, height, 1)
    trg = load_labels(trgFile)
    trg = trg[0:n]

    return inp, trg, width, height


def loadData(nTrn, nTst):
    # Load data
    (trnInp, trnTrg, imgW, imgH) = loadImages("polyAll-trn", "polyAll-trn_trg.csv", nTrn)
    (tstInp, tstTrg, imgW, imgH) = loadImages("polyAll-tst", "polyAll-tst_trg.csv", nTst)

    if tf.keras.backend.image_data_format() == 'channels_first':
        trnInp = trnInp.reshape(trnInp.shape[0], 1, imgH, imgW)
        tstInp = tstInp.reshape(tstInp.shape[0], 1, imgH, imgW)
        input_shape = (1, imgH, imgW)
    else:
        trnInp = trnInp.reshape(trnInp.shape[0], imgH, imgW, 1)
        tstInp = tstInp.reshape(tstInp.shape[0], imgH, imgW, 1)
        input_shape = (imgH, imgW, 1)

    #print('trnInp shape:', trnInp.shape)
    #print('tstInp shape:', tstInp.shape)

    #trnTrg /= 10;
    #tstTrg /= 10;
    
    #sanna convert so that 0 means 3 and 7 means 10 etc
    trnTrg -= 3;
    tstTrg -= 3;

    return trnInp, trnTrg, tstInp, tstTrg, input_shape

# %% [markdown]
# Load and plot some example images

# %%
xplot, yplot, xplot2, yplot2, plotdata_shape = loadData(10,10)

print('Dimensions of images: ' , plotdata_shape)

plt.figure(1, figsize=(15,10))
plt.imshow(xplot[:10,:,:].swapaxes(0,1).reshape(100,10*100),cmap="gray")
plt.axis("off")
#plt.savefig('example_data')
print("Targets:")
print(yplot[:10])
print('acctual number of corners: ', yplot[:10]+3)
# Out:
# Dimensions of images:  (100, 100, 1)
# Targets:
# [2. 6. 3. 7. 3. 2. 2. 3. 1. 6.]
# acctual number of corners:  [ 5.  9.  6. 10.  6.  5.  5.  6.  4.  9.]

# %% [markdown]
# * load the dataset: training data and test data
# * Make images binary (optional)
# * Reserve 20% of the training data for validation

# %%
# Load the dataset
xtrain, ytrain, xtest, ytest, input_shape = loadData(5000,5000)

print('xtrain shape' , xtrain.shape)

#pre-proprocessing
# make all pixels < threshold black
#threshold = 0.1
#xtrain = 1.0 * (xtrain_in > threshold)
#xtest = 1.0 * (xtest_in > threshold)

# Reserve some samples for validation
val_param = int(xtrain.shape[0]*0.2)
print('Size of validation set: ', val_param)
xval = xtrain[0:val_param]
yval = ytrain[0:val_param]
xtrain = xtrain[val_param:]
ytrain = ytrain[val_param:]
# Out:
# xtrain shape (4000, 100, 100, 1)
# xtest shape (10, 100, 100, 1)
# Size of validation set:  2

# %% [markdown]
# ## CNN architecture

# %% [markdown]
# Watch out for Overfitting: if you train too much on your training data, you minimize the error function more, but the model works worse on unseen data
#
#
# Padding could be useful for us since corners are close to the edges of the images in many examples .

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3, 3),
           activation='relu',input_shape=input_shape,padding='same'),
    Conv2D(16, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(3, 3), activation='relu',padding='same'),
    Conv2D(32, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu',kernel_regularizer= regularizers.l1_l2(0.0008,0.008)),
    Dropout(0.5),
    Dense(8),
    Activation('softmax')
])

# %% [markdown]
# Define training configuration (optimizer, loss, metrics)

# %%
# the loss function, optimation function
adam = Adam(learning_rate=0.005)
#rms = RMSprop(learning_rate=0.008)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 16)      160
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 8)                 1032
#
#  activation (Activation)     (None, 8)                 0
#
# =================================================================
# Total params: 340,184
# Trainable params: 340,184
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model
#
# Train the model with the training data and validate with the validation data.

# %%
estimator = model.fit(xtrain, ytrain, 
                      epochs=150, 
                      batch_size=200, #64, #300,
                      verbose=1,
                      validation_data=(xval, yval))


estimator.history
print('Accuracy: ', estimator.history['accuracy'][-1])
print(' Validation accuracy: ', estimator.history['val_accuracy'][-1])
# Out:
# Epoch 1/150
# 20/20 [==============================] - 10s 446ms/step - loss: 4.2806 - accuracy: 0.1482 - val_loss: 2.7469 - val_accuracy: 0.2180
# Epoch 2/150
# 20/20 [==============================] - 9s 461ms/step - loss: 2.5309 - accuracy: 0.2240 - val_loss: 2.2833 - val_accuracy: 0.2510
# Epoch 3/150
# 20/20 [==============================] - 10s 489ms/step - loss: 2.2383 - accuracy: 0.2565 - val_loss: 2.1123 - val_accuracy: 0.2600
# Epoch 4/150
# 20/20 [==============================] - 10s 497ms/step - loss: 2.1209 - accuracy: 0.2848 - val_loss: 2.0732 - val_accuracy: 0.3010
# Epoch 5/150
# 20/20 [==============================] - 10s 518ms/step - loss: 2.0734 - accuracy: 0.2955 - val_loss: 1.9810 - val_accuracy: 0.3170
# Epoch 6/150
# 20/20 [==============================] - 11s 548ms/step - loss: 2.0092 - accuracy: 0.3212 - val_loss: 1.9286 - val_accuracy: 0.3010
# Epoch 7/150
# 20/20 [==============================] - 11s 543ms/step - loss: 1.9567 - accuracy: 0.3338 - val_loss: 1.9392 - val_accuracy: 0.3620
# Epoch 8/150
# 20/20 [==============================] - 10s 513ms/step - loss: 1.9511 - accuracy: 0.3358 - val_loss: 1.9137 - val_accuracy: 0.3450
# Epoch 9/150
# 20/20 [==============================] - 10s 511ms/step - loss: 1.8660 - accuracy: 0.3692 - val_loss: 1.7448 - val_accuracy: 0.4020
# Epoch 10/150
# 20/20 [==============================] - 10s 503ms/step - loss: 1.7758 - accuracy: 0.3862 - val_loss: 1.7187 - val_accuracy: 0.4010
# Epoch 11/150
# 20/20 [==============================] - 10s 476ms/step - loss: 1.7666 - accuracy: 0.4072 - val_loss: 1.6866 - val_accuracy: 0.4260
# Epoch 12/150
# 20/20 [==============================] - 9s 443ms/step - loss: 1.7286 - accuracy: 0.4055 - val_loss: 1.6385 - val_accuracy: 0.4510
# Epoch 13/150
# 20/20 [==============================] - 11s 528ms/step - loss: 1.6643 - accuracy: 0.4552 - val_loss: 1.6622 - val_accuracy: 0.4670
# Epoch 14/150
# 20/20 [==============================] - 10s 502ms/step - loss: 1.5797 - accuracy: 0.4865 - val_loss: 1.5822 - val_accuracy: 0.4530
# Epoch 15/150
# 20/20 [==============================] - 10s 505ms/step - loss: 1.5716 - accuracy: 0.4785 - val_loss: 1.4907 - val_accuracy: 0.5180
# Epoch 16/150
# 20/20 [==============================] - 10s 506ms/step - loss: 1.5039 - accuracy: 0.5138 - val_loss: 1.5361 - val_accuracy: 0.5290
# Epoch 17/150
# 20/20 [==============================] - 10s 514ms/step - loss: 1.5673 - accuracy: 0.4935 - val_loss: 1.5072 - val_accuracy: 0.5000
# Epoch 18/150
# 20/20 [==============================] - 10s 494ms/step - loss: 1.5007 - accuracy: 0.5110 - val_loss: 1.4514 - val_accuracy: 0.5150
# Epoch 19/150
# 20/20 [==============================] - 9s 477ms/step - loss: 1.4519 - accuracy: 0.5353 - val_loss: 1.4282 - val_accuracy: 0.5570
# Epoch 20/150
# 20/20 [==============================] - 11s 557ms/step - loss: 1.4428 - accuracy: 0.5368 - val_loss: 1.4008 - val_accuracy: 0.5590
# Epoch 21/150
# 20/20 [==============================] - 11s 529ms/step - loss: 1.4047 - accuracy: 0.5497 - val_loss: 1.5084 - val_accuracy: 0.5010
# Epoch 22/150
# 20/20 [==============================] - 10s 495ms/step - loss: 1.4502 - accuracy: 0.5213 - val_loss: 1.3877 - val_accuracy: 0.5300
# Epoch 23/150
# 20/20 [==============================] - 10s 515ms/step - loss: 1.3787 - accuracy: 0.5602 - val_loss: 1.3525 - val_accuracy: 0.5780
# Epoch 24/150
# 20/20 [==============================] - 11s 565ms/step - loss: 1.3471 - accuracy: 0.5690 - val_loss: 1.3229 - val_accuracy: 0.5820
# Epoch 25/150
# 20/20 [==============================] - 12s 600ms/step - loss: 1.3448 - accuracy: 0.5663 - val_loss: 1.3348 - val_accuracy: 0.5850
# Epoch 26/150
# 20/20 [==============================] - 13s 650ms/step - loss: 1.2981 - accuracy: 0.5890 - val_loss: 1.2777 - val_accuracy: 0.5830
# Epoch 27/150
# 20/20 [==============================] - 15s 746ms/step - loss: 1.3010 - accuracy: 0.5810 - val_loss: 1.3330 - val_accuracy: 0.5870
# Epoch 28/150
# 20/20 [==============================] - 14s 677ms/step - loss: 1.2974 - accuracy: 0.5875 - val_loss: 1.5406 - val_accuracy: 0.5180
# Epoch 29/150
# 20/20 [==============================] - 12s 621ms/step - loss: 1.3023 - accuracy: 0.5770 - val_loss: 1.3261 - val_accuracy: 0.5730
# Epoch 30/150
# 20/20 [==============================] - 12s 620ms/step - loss: 1.2559 - accuracy: 0.6148 - val_loss: 1.2604 - val_accuracy: 0.6080
# Epoch 31/150
# 20/20 [==============================] - 12s 617ms/step - loss: 1.2805 - accuracy: 0.6022 - val_loss: 1.3055 - val_accuracy: 0.5810
# Epoch 32/150
# 20/20 [==============================] - 15s 742ms/step - loss: 1.2770 - accuracy: 0.6137 - val_loss: 1.2361 - val_accuracy: 0.6190
# Epoch 33/150
# 20/20 [==============================] - 13s 670ms/step - loss: 1.2958 - accuracy: 0.5995 - val_loss: 1.2513 - val_accuracy: 0.6120
# Epoch 34/150
# 20/20 [==============================] - 14s 694ms/step - loss: 1.2166 - accuracy: 0.6450 - val_loss: 1.4009 - val_accuracy: 0.5830
# Epoch 35/150
# 20/20 [==============================] - 13s 637ms/step - loss: 1.2264 - accuracy: 0.6223 - val_loss: 1.2121 - val_accuracy: 0.6320
# Epoch 36/150
# 20/20 [==============================] - 14s 690ms/step - loss: 1.1681 - accuracy: 0.6395 - val_loss: 1.1986 - val_accuracy: 0.6600
# Epoch 37/150
# 20/20 [==============================] - 14s 714ms/step - loss: 1.1766 - accuracy: 0.6350 - val_loss: 1.2438 - val_accuracy: 0.6160
# Epoch 38/150
# 20/20 [==============================] - 14s 701ms/step - loss: 1.1920 - accuracy: 0.6365 - val_loss: 1.2047 - val_accuracy: 0.6170
# Epoch 39/150
# 20/20 [==============================] - 14s 682ms/step - loss: 1.2111 - accuracy: 0.6165 - val_loss: 1.1841 - val_accuracy: 0.6430
# Epoch 40/150
# 20/20 [==============================] - 14s 670ms/step - loss: 1.1891 - accuracy: 0.6292 - val_loss: 1.3605 - val_accuracy: 0.6100
# Epoch 41/150
# 20/20 [==============================] - 13s 650ms/step - loss: 1.1746 - accuracy: 0.6398 - val_loss: 1.1738 - val_accuracy: 0.6580
# Epoch 42/150
# 20/20 [==============================] - 13s 675ms/step - loss: 1.1617 - accuracy: 0.6465 - val_loss: 1.1797 - val_accuracy: 0.6540
# Epoch 43/150
# 20/20 [==============================] - 14s 715ms/step - loss: 1.1722 - accuracy: 0.6532 - val_loss: 1.1903 - val_accuracy: 0.6460
# Epoch 44/150
# 20/20 [==============================] - 14s 688ms/step - loss: 1.1133 - accuracy: 0.6758 - val_loss: 1.4090 - val_accuracy: 0.5200
# Epoch 45/150
# 20/20 [==============================] - 14s 696ms/step - loss: 1.1554 - accuracy: 0.6647 - val_loss: 1.1815 - val_accuracy: 0.6320
# Epoch 46/150
# 20/20 [==============================] - 15s 732ms/step - loss: 1.1724 - accuracy: 0.6435 - val_loss: 1.2054 - val_accuracy: 0.6300
# Epoch 47/150
# 20/20 [==============================] - 14s 710ms/step - loss: 1.1067 - accuracy: 0.6768 - val_loss: 1.2999 - val_accuracy: 0.6050
# Epoch 48/150
# 20/20 [==============================] - 13s 628ms/step - loss: 1.1347 - accuracy: 0.6557 - val_loss: 1.1773 - val_accuracy: 0.6760
# Epoch 49/150
# 20/20 [==============================] - 14s 701ms/step - loss: 1.1286 - accuracy: 0.6758 - val_loss: 1.1690 - val_accuracy: 0.6640
# Epoch 50/150
# 20/20 [==============================] - 14s 685ms/step - loss: 1.1276 - accuracy: 0.6752 - val_loss: 1.1819 - val_accuracy: 0.6680
# Epoch 51/150
# 20/20 [==============================] - 14s 678ms/step - loss: 1.0995 - accuracy: 0.6825 - val_loss: 1.2297 - val_accuracy: 0.6170
# Epoch 52/150
# 20/20 [==============================] - 12s 579ms/step - loss: 1.1183 - accuracy: 0.6712 - val_loss: 1.6945 - val_accuracy: 0.5010
# Epoch 53/150
# 20/20 [==============================] - 13s 656ms/step - loss: 1.2495 - accuracy: 0.5920 - val_loss: 1.2084 - val_accuracy: 0.6580
# Epoch 54/150
# 20/20 [==============================] - 14s 704ms/step - loss: 1.1135 - accuracy: 0.6737 - val_loss: 1.1535 - val_accuracy: 0.6580
# Epoch 55/150
# 20/20 [==============================] - 12s 590ms/step - loss: 1.0435 - accuracy: 0.7060 - val_loss: 1.1915 - val_accuracy: 0.6780
# Epoch 56/150
# 20/20 [==============================] - 13s 651ms/step - loss: 1.0656 - accuracy: 0.6948 - val_loss: 1.1190 - val_accuracy: 0.6640
# Epoch 57/150
# 20/20 [==============================] - 14s 707ms/step - loss: 1.0522 - accuracy: 0.7020 - val_loss: 1.1486 - val_accuracy: 0.6680
# Epoch 58/150
# 20/20 [==============================] - 14s 676ms/step - loss: 1.1331 - accuracy: 0.6587 - val_loss: 1.4315 - val_accuracy: 0.5980
# Epoch 59/150
# 20/20 [==============================] - 14s 683ms/step - loss: 1.2276 - accuracy: 0.6212 - val_loss: 1.3095 - val_accuracy: 0.6240
# Epoch 60/150
# 20/20 [==============================] - 14s 724ms/step - loss: 1.0723 - accuracy: 0.6973 - val_loss: 1.2274 - val_accuracy: 0.6060
# Epoch 61/150
# 20/20 [==============================] - 14s 707ms/step - loss: 1.0604 - accuracy: 0.7063 - val_loss: 1.1231 - val_accuracy: 0.6830
# Epoch 62/150
# 20/20 [==============================] - 13s 647ms/step - loss: 1.0070 - accuracy: 0.7258 - val_loss: 1.1510 - val_accuracy: 0.6590
# Epoch 63/150
# 20/20 [==============================] - 14s 690ms/step - loss: 0.9997 - accuracy: 0.7415 - val_loss: 1.2223 - val_accuracy: 0.6800
# Epoch 64/150
# 20/20 [==============================] - 14s 692ms/step - loss: 1.0650 - accuracy: 0.7070 - val_loss: 1.2376 - val_accuracy: 0.6520
# Epoch 65/150
# 20/20 [==============================] - 13s 674ms/step - loss: 1.1378 - accuracy: 0.6672 - val_loss: 1.3092 - val_accuracy: 0.5780
# Epoch 66/150
# 20/20 [==============================] - 13s 654ms/step - loss: 1.1186 - accuracy: 0.6933 - val_loss: 1.2227 - val_accuracy: 0.6290
# Epoch 67/150
# 20/20 [==============================] - 14s 710ms/step - loss: 1.0881 - accuracy: 0.6952 - val_loss: 1.2443 - val_accuracy: 0.6640
# Epoch 68/150
# 20/20 [==============================] - 14s 690ms/step - loss: 1.0146 - accuracy: 0.7200 - val_loss: 1.1538 - val_accuracy: 0.6830
# Epoch 69/150
# 20/20 [==============================] - 14s 689ms/step - loss: 1.0613 - accuracy: 0.6992 - val_loss: 1.1441 - val_accuracy: 0.6490
# Epoch 70/150
# 20/20 [==============================] - 14s 680ms/step - loss: 1.0355 - accuracy: 0.7060 - val_loss: 1.2658 - val_accuracy: 0.6360
# Epoch 71/150
# 20/20 [==============================] - 14s 686ms/step - loss: 1.0929 - accuracy: 0.6845 - val_loss: 1.2302 - val_accuracy: 0.6290
# Epoch 72/150
# 20/20 [==============================] - 13s 640ms/step - loss: 1.0470 - accuracy: 0.7128 - val_loss: 1.3267 - val_accuracy: 0.6610
# Epoch 73/150
# 20/20 [==============================] - 12s 616ms/step - loss: 1.0741 - accuracy: 0.6935 - val_loss: 1.2147 - val_accuracy: 0.6610
# Epoch 74/150
# 20/20 [==============================] - 13s 666ms/step - loss: 1.0017 - accuracy: 0.7297 - val_loss: 1.1733 - val_accuracy: 0.6480
# Epoch 75/150
# 20/20 [==============================] - 13s 675ms/step - loss: 1.0028 - accuracy: 0.7237 - val_loss: 1.1905 - val_accuracy: 0.6590
# Epoch 76/150
# 20/20 [==============================] - 14s 697ms/step - loss: 0.9489 - accuracy: 0.7545 - val_loss: 1.2489 - val_accuracy: 0.6710
# Epoch 77/150
# 20/20 [==============================] - 13s 663ms/step - loss: 0.9343 - accuracy: 0.7613 - val_loss: 1.1624 - val_accuracy: 0.6670
# Epoch 78/150
# 20/20 [==============================] - 12s 602ms/step - loss: 0.9397 - accuracy: 0.7555 - val_loss: 1.1312 - val_accuracy: 0.6750
# Epoch 79/150
# 20/20 [==============================] - 12s 597ms/step - loss: 0.9653 - accuracy: 0.7423 - val_loss: 1.2647 - val_accuracy: 0.6570
# Epoch 80/150
# 20/20 [==============================] - 14s 693ms/step - loss: 0.9772 - accuracy: 0.7467 - val_loss: 1.1460 - val_accuracy: 0.6490
# Epoch 81/150
# 20/20 [==============================] - 15s 723ms/step - loss: 0.9606 - accuracy: 0.7487 - val_loss: 1.1477 - val_accuracy: 0.6920
# Epoch 82/150
# 20/20 [==============================] - 14s 689ms/step - loss: 1.0413 - accuracy: 0.7082 - val_loss: 1.1783 - val_accuracy: 0.6750
# Epoch 83/150
# 20/20 [==============================] - 13s 660ms/step - loss: 1.0358 - accuracy: 0.7170 - val_loss: 1.1988 - val_accuracy: 0.6560
# Epoch 84/150
# 20/20 [==============================] - 13s 638ms/step - loss: 0.9801 - accuracy: 0.7573 - val_loss: 1.1933 - val_accuracy: 0.6570
# Epoch 85/150
# 20/20 [==============================] - 14s 687ms/step - loss: 0.9767 - accuracy: 0.7452 - val_loss: 1.1843 - val_accuracy: 0.6620
# Epoch 86/150
# 20/20 [==============================] - 14s 686ms/step - loss: 0.9756 - accuracy: 0.7540 - val_loss: 1.3280 - val_accuracy: 0.6680
# Epoch 87/150
# 20/20 [==============================] - 13s 640ms/step - loss: 1.0325 - accuracy: 0.7215 - val_loss: 1.4758 - val_accuracy: 0.6170
# Epoch 88/150
# 20/20 [==============================] - 13s 652ms/step - loss: 1.0752 - accuracy: 0.6898 - val_loss: 1.3664 - val_accuracy: 0.5750
# Epoch 89/150
# 20/20 [==============================] - 14s 678ms/step - loss: 1.0149 - accuracy: 0.7340 - val_loss: 1.2241 - val_accuracy: 0.6960
# Epoch 90/150
# 20/20 [==============================] - 14s 692ms/step - loss: 0.9347 - accuracy: 0.7705 - val_loss: 1.1323 - val_accuracy: 0.6850
# Epoch 91/150
# 20/20 [==============================] - 13s 656ms/step - loss: 0.9575 - accuracy: 0.7475 - val_loss: 1.1724 - val_accuracy: 0.6620
# Epoch 92/150
# 20/20 [==============================] - 14s 682ms/step - loss: 0.9390 - accuracy: 0.7552 - val_loss: 1.2207 - val_accuracy: 0.6890
# Epoch 93/150
# 20/20 [==============================] - 14s 678ms/step - loss: 0.9403 - accuracy: 0.7670 - val_loss: 1.2164 - val_accuracy: 0.6690
# Epoch 94/150
# 20/20 [==============================] - 14s 712ms/step - loss: 0.9379 - accuracy: 0.7730 - val_loss: 1.2056 - val_accuracy: 0.7040
# Epoch 95/150
# 20/20 [==============================] - 14s 708ms/step - loss: 0.9370 - accuracy: 0.7710 - val_loss: 1.3140 - val_accuracy: 0.6010
# Epoch 96/150
# 20/20 [==============================] - 13s 671ms/step - loss: 1.0060 - accuracy: 0.7322 - val_loss: 1.3144 - val_accuracy: 0.6770
# Epoch 97/150
# 20/20 [==============================] - 18s 924ms/step - loss: 0.9410 - accuracy: 0.7695 - val_loss: 1.2107 - val_accuracy: 0.6900
# Epoch 98/150
# 20/20 [==============================] - 14s 702ms/step - loss: 0.9706 - accuracy: 0.7565 - val_loss: 1.4130 - val_accuracy: 0.6550
# Epoch 99/150
# 20/20 [==============================] - 13s 668ms/step - loss: 1.0080 - accuracy: 0.7412 - val_loss: 1.1633 - val_accuracy: 0.6660
# Epoch 100/150
# 20/20 [==============================] - 14s 701ms/step - loss: 1.0392 - accuracy: 0.7215 - val_loss: 1.2030 - val_accuracy: 0.6770
# Epoch 101/150
# 20/20 [==============================] - 14s 686ms/step - loss: 0.9604 - accuracy: 0.7550 - val_loss: 1.5226 - val_accuracy: 0.6160
# Epoch 102/150
# 20/20 [==============================] - 14s 707ms/step - loss: 0.9910 - accuracy: 0.7470 - val_loss: 1.1928 - val_accuracy: 0.6630
# Epoch 103/150
# 20/20 [==============================] - 14s 694ms/step - loss: 1.0434 - accuracy: 0.7210 - val_loss: 1.4661 - val_accuracy: 0.6370
# Epoch 104/150
# 20/20 [==============================] - 13s 651ms/step - loss: 0.9812 - accuracy: 0.7487 - val_loss: 1.2675 - val_accuracy: 0.6700
# Epoch 105/150
# 20/20 [==============================] - 14s 717ms/step - loss: 0.8977 - accuracy: 0.7880 - val_loss: 1.2612 - val_accuracy: 0.6970
# Epoch 106/150
# 20/20 [==============================] - 12s 618ms/step - loss: 0.9933 - accuracy: 0.7423 - val_loss: 1.1511 - val_accuracy: 0.6680
# Epoch 107/150
# 20/20 [==============================] - 13s 636ms/step - loss: 0.8983 - accuracy: 0.7910 - val_loss: 1.2281 - val_accuracy: 0.6780
# Epoch 108/150
# 20/20 [==============================] - 13s 650ms/step - loss: 0.8738 - accuracy: 0.7922 - val_loss: 1.2436 - val_accuracy: 0.7020
# Epoch 109/150
# 20/20 [==============================] - 15s 743ms/step - loss: 0.8705 - accuracy: 0.7912 - val_loss: 1.1979 - val_accuracy: 0.7040
# Epoch 110/150
# 20/20 [==============================] - 13s 679ms/step - loss: 0.8639 - accuracy: 0.7933 - val_loss: 1.1792 - val_accuracy: 0.6770
# Epoch 111/150
# 20/20 [==============================] - 13s 653ms/step - loss: 0.8971 - accuracy: 0.7785 - val_loss: 1.2755 - val_accuracy: 0.6540
# Epoch 112/150
# 20/20 [==============================] - 14s 722ms/step - loss: 0.8838 - accuracy: 0.7845 - val_loss: 1.1709 - val_accuracy: 0.7100
# Epoch 113/150
# 20/20 [==============================] - 14s 676ms/step - loss: 0.9351 - accuracy: 0.7610 - val_loss: 1.1964 - val_accuracy: 0.6820
# Epoch 114/150
# 20/20 [==============================] - 14s 692ms/step - loss: 0.9077 - accuracy: 0.7740 - val_loss: 1.1572 - val_accuracy: 0.7040
# Epoch 115/150
# 20/20 [==============================] - 13s 648ms/step - loss: 0.9297 - accuracy: 0.7753 - val_loss: 1.5702 - val_accuracy: 0.6180
# Epoch 116/150
# 20/20 [==============================] - 14s 691ms/step - loss: 0.9565 - accuracy: 0.7682 - val_loss: 1.1707 - val_accuracy: 0.6930
# Epoch 117/150
# 20/20 [==============================] - 13s 649ms/step - loss: 0.8851 - accuracy: 0.8002 - val_loss: 1.2090 - val_accuracy: 0.6830
# Epoch 118/150
# 20/20 [==============================] - 13s 653ms/step - loss: 0.9052 - accuracy: 0.7890 - val_loss: 1.1907 - val_accuracy: 0.6870
# Epoch 119/150
# 20/20 [==============================] - 13s 659ms/step - loss: 0.8793 - accuracy: 0.8002 - val_loss: 1.3442 - val_accuracy: 0.6970
# Epoch 120/150
# 20/20 [==============================] - 12s 603ms/step - loss: 0.9269 - accuracy: 0.7705 - val_loss: 1.3292 - val_accuracy: 0.6970
# Epoch 121/150
# 20/20 [==============================] - 12s 624ms/step - loss: 0.9179 - accuracy: 0.7720 - val_loss: 1.3439 - val_accuracy: 0.6760
# Epoch 122/150
# 20/20 [==============================] - 13s 671ms/step - loss: 0.8950 - accuracy: 0.7945 - val_loss: 1.2394 - val_accuracy: 0.7100
# Epoch 123/150
# 20/20 [==============================] - 13s 649ms/step - loss: 0.8595 - accuracy: 0.8058 - val_loss: 1.2240 - val_accuracy: 0.6750
# Epoch 124/150
# 20/20 [==============================] - 12s 623ms/step - loss: 0.9526 - accuracy: 0.7607 - val_loss: 1.2202 - val_accuracy: 0.6860
# Epoch 125/150
# 20/20 [==============================] - 14s 688ms/step - loss: 0.9461 - accuracy: 0.7617 - val_loss: 1.1900 - val_accuracy: 0.7070
# Epoch 126/150
# 20/20 [==============================] - 13s 653ms/step - loss: 0.9315 - accuracy: 0.7805 - val_loss: 1.2951 - val_accuracy: 0.6840
# Epoch 127/150
# 20/20 [==============================] - 13s 654ms/step - loss: 0.9234 - accuracy: 0.7732 - val_loss: 1.1805 - val_accuracy: 0.6770
# Epoch 128/150
# 20/20 [==============================] - 14s 685ms/step - loss: 0.8672 - accuracy: 0.7983 - val_loss: 1.1697 - val_accuracy: 0.6980
# Epoch 129/150
# 20/20 [==============================] - 13s 646ms/step - loss: 0.8514 - accuracy: 0.8070 - val_loss: 1.3034 - val_accuracy: 0.6500
# Epoch 130/150
# 20/20 [==============================] - 13s 669ms/step - loss: 0.8992 - accuracy: 0.7855 - val_loss: 1.3533 - val_accuracy: 0.6140
# Epoch 131/150
# 20/20 [==============================] - 13s 666ms/step - loss: 1.0778 - accuracy: 0.7082 - val_loss: 1.6628 - val_accuracy: 0.4670
# Epoch 132/150
# 20/20 [==============================] - 13s 620ms/step - loss: 1.2249 - accuracy: 0.6240 - val_loss: 1.2276 - val_accuracy: 0.6210
# Epoch 133/150
# 20/20 [==============================] - 14s 677ms/step - loss: 1.0577 - accuracy: 0.7222 - val_loss: 1.2151 - val_accuracy: 0.6750
# Epoch 134/150
# 20/20 [==============================] - 13s 670ms/step - loss: 0.9432 - accuracy: 0.7810 - val_loss: 1.2704 - val_accuracy: 0.6880
# Epoch 135/150
# 20/20 [==============================] - 13s 638ms/step - loss: 0.9529 - accuracy: 0.7720 - val_loss: 1.3236 - val_accuracy: 0.6480
# Epoch 136/150
# 20/20 [==============================] - 13s 632ms/step - loss: 0.9823 - accuracy: 0.7545 - val_loss: 1.3331 - val_accuracy: 0.6970
# Epoch 137/150
# 20/20 [==============================] - 13s 641ms/step - loss: 0.9167 - accuracy: 0.7713 - val_loss: 1.3104 - val_accuracy: 0.6480
# Epoch 138/150
# 20/20 [==============================] - 14s 696ms/step - loss: 0.9093 - accuracy: 0.7797 - val_loss: 1.2561 - val_accuracy: 0.6950
# Epoch 139/150
# 20/20 [==============================] - 14s 677ms/step - loss: 0.8678 - accuracy: 0.7935 - val_loss: 1.3388 - val_accuracy: 0.7000
# Epoch 140/150
# 20/20 [==============================] - 13s 675ms/step - loss: 0.9130 - accuracy: 0.7782 - val_loss: 1.2538 - val_accuracy: 0.7060
# Epoch 141/150
# 20/20 [==============================] - 13s 639ms/step - loss: 0.8562 - accuracy: 0.8112 - val_loss: 1.1979 - val_accuracy: 0.7040
# Epoch 142/150
# 20/20 [==============================] - 14s 697ms/step - loss: 0.8916 - accuracy: 0.8045 - val_loss: 1.2208 - val_accuracy: 0.7030
# Epoch 143/150
# 20/20 [==============================] - 14s 680ms/step - loss: 0.8592 - accuracy: 0.8010 - val_loss: 1.1788 - val_accuracy: 0.7080
# Epoch 144/150
# 20/20 [==============================] - 14s 690ms/step - loss: 0.8353 - accuracy: 0.8135 - val_loss: 1.2349 - val_accuracy: 0.6640
# Epoch 145/150
# 20/20 [==============================] - 13s 675ms/step - loss: 0.9075 - accuracy: 0.7715 - val_loss: 1.1912 - val_accuracy: 0.6670
# Epoch 146/150
# 20/20 [==============================] - 14s 682ms/step - loss: 0.9689 - accuracy: 0.7448 - val_loss: 1.2255 - val_accuracy: 0.6300
# Epoch 147/150
# 20/20 [==============================] - 13s 671ms/step - loss: 1.0436 - accuracy: 0.7113 - val_loss: 1.5739 - val_accuracy: 0.5490
# Epoch 148/150
# 20/20 [==============================] - 13s 675ms/step - loss: 1.0619 - accuracy: 0.7075 - val_loss: 1.2706 - val_accuracy: 0.6530
# Epoch 149/150
# 20/20 [==============================] - 14s 688ms/step - loss: 1.0206 - accuracy: 0.7138 - val_loss: 1.4053 - val_accuracy: 0.5810
# Epoch 150/150
# 20/20 [==============================] - 13s 641ms/step - loss: 0.9758 - accuracy: 0.7465 - val_loss: 1.3347 - val_accuracy: 0.6180
# Accuracy:  0.7465000152587891
#  Validation accuracy:  0.6179999709129333

# %% [markdown]
# Training and validation plots

# %%
plt.figure(1, figsize=(9,6))
plt.subplot(121)
# Plot the training error
plt.plot(estimator.history['loss'], label='Training')
plt.plot(estimator.history['val_loss'], label='Validation')
plt.ylabel('Error')
plt.xlabel('epoch')
plt.legend()
#plt.show()

# Plot the accuracy
plt.subplot(122)
plt.plot(estimator.history['accuracy'], label='Training')
plt.plot(estimator.history['val_accuracy'], label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend()

# %% [markdown]
# # Evaluate
# Time to evaluate the model with the test data

# %%
print('Evaluating model: ')
scores = model.evaluate(xtest, ytest, batch_size=128) #prints out score. You can use a batch size here too : , batch_size=128
print("test loss, test acc:", round(scores[0],4), round(scores[1],4))
# Out:
# Evaluating model:
# 1/1 [==============================] - 0s 95ms/step - loss: 2.0450 - accuracy: 0.4000
# test loss, test acc: 2.045 0.4

# %% [markdown]
# # Results summary
#
# - Around 72% polygones were correctly classified
# - Model is slightly overtrained

# %% [markdown]
# # What went wrong? Examples of correct and wrongly classified polygons
#
# * Showing typical example of polygons that were harder to identify
# * Display the filters
#
#
# Starting with a correctly classified polygon:

# %% [markdown]
# ![image.png](attachment:8e1adfae-3935-4bd9-ad91-565a45e82f29.png)

# %% [markdown]
# the filters convoluted with this polygon look like this:
# ![image.png](attachment:8f58da4a-52d7-4011-84ad-cc0ad7e27c93.png)

# %% [markdown]
# and an example of a wrongly classified polygon:

# %% [markdown]
# ![image.png](attachment:47282e62-d79b-4b5f-92a9-4d964a72c9a0.png) classified as:
#
# ![image.png](attachment:3eb18578-b4f7-415b-886e-efada08f73f1.png)

# %% [markdown]
# Note that:
# * one of the corners are close to 180 degrees which is most probably the corner that is not counted
# * there is an existing, but lower, propability for 5 corners

# %% [markdown]
# ![image.png](attachment:74562289-33bf-4b52-a37b-fda78a1fbda5.png)
